# %%
! pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/34/ac/72a4e42e76bf549dfd91791a6b10a9832f046c1d48b5e778be9ec012aa47/wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\pawan\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\pawan\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\pawan\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pawan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\pawan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pawan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pawan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pawan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pawan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pawan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pawan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.2-cp311-cp311-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/151.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/151.4 kB ? eta -:--:--
#    ---------- ----------------------------- 41.0/151.4 kB 93.7 kB/s eta 0:00:02
#    --------------- ----------------------- 61.4/151.4 kB 142.6 kB/s eta 0:00:01
#    ----------------------- --------------- 92.2/151.4 kB 194.1 kB/s eta 0:00:01
#    ---------------------------- --------- 112.6/151.4 kB 226.0 kB/s eta 0:00:01
#    ------------------------------ ------- 122.9/151.4 kB 218.7 kB/s eta 0:00:01
#    -------------------------------------- 151.4/151.4 kB 251.2 kB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
! pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ---------------------------------------- 0.0/636.8 kB ? eta -:--:--
#      --- ----------------------------------- 61.4/636.8 kB 1.1 MB/s eta 0:00:01
#      --- ----------------------------------- 61.4/636.8 kB 1.1 MB/s eta 0:00:01
#      ----------- -------------------------- 194.6/636.8 kB 1.5 MB/s eta 0:00:01
#      --------------------- ---------------- 358.4/636.8 kB 1.9 MB/s eta 0:00:01
#      ------------------------------------ - 614.4/636.8 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 636.8/636.8 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.1 in c:\users\pawan\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\pawan\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\pawan\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pawan\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\pawan\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\pawan\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1

# %%
import os 
import re


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from textblob import TextBlob

# %%
def generate_wordcloud(text):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
        # Display the word cloud
    plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title("Word Cloud for all reviews")
    plt.show()

# %%
def get_sentiment(df):
    # Compute sentiment for each review
    df['Sentiment'] = df['Review'].apply(lambda x: TextBlob(x).sentiment.polarity)
    # Calculate the year-on-year average sentiment
    yearly_avg_sentiment = df.groupby('Year')['Sentiment'].mean().reset_index()
    plt.figure(figsize=(15, 7))
    plt.plot(yearly_avg_sentiment['Year'], yearly_avg_sentiment['Sentiment'], marker='o', color='b')
    plt.title('Year on Year Average Sentiment')
    plt.xlabel('Year')
    plt.ylabel('Average Sentiment')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()
    plt.show()

# %%
def get_year_wise_reviews(df):
    review_counts = df.groupby('Year').size().reset_index(name='Number of Reviews')
    # Plotting the review counts
    plt.figure(figsize=(12, 6))
    plt.plot(review_counts['Year'], review_counts['Number of Reviews'], marker='o', color='b')
    plt.title('Number of Reviews Year-on-Year')
    plt.xlabel('Year')
    plt.ylabel('Number of Reviews')
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # GAP

# %%
df_gap = pd.read_csv(os.path.join(os.getcwd(), 'data','gap-reviews.csv'),encoding= 'latin1')
combined_text = ' '.join(df_gap.iloc[:, 1].astype(str))

combined_text = combined_text.lower().replace('app', '')
combined_text = combined_text.lower().replace('gap', '')

# %%
# Generate the word cloud
wordcloud = generate_wordcloud(combined_text)

# %%
get_sentiment(df_gap)

# %%
get_year_wise_reviews(df_gap)

# %% [markdown]
# # Banana Republic

# %%
df_br = pd.read_csv(os.path.join(os.getcwd(),'data', 'banana-reviews.csv'))
combined_text = ' '.join(df_br.iloc[:, 1].astype(str))
combined_text = combined_text.lower().replace('app', '')
combined_text = combined_text.lower().replace('BR', '')

# %%
# Generate the word cloud
wordcloud = generate_wordcloud(combined_text)

# %%
get_sentiment(df_br)

# %%
get_year_wise_reviews(df_br)

# %% [markdown]
# # Old Navy

# %%
df_old = pd.read_csv(os.path.join(os.getcwd(), 'data', 'oldnavy-reviews.csv'))
combined_text = ' '.join(df_old.iloc[:, 1].astype(str))
combined_text = combined_text.lower().replace('app', '')
combined_text = combined_text.replace('old', '')
combined_text = combined_text.replace('navy', '')
combined_text = combined_text.replace('old navy', '')

# %%
# Generate the word cloud
wordcloud = generate_wordcloud(combined_text)

# %%
get_sentiment(df_old)

# %%
get_year_wise_reviews(df_old)

# %% [markdown]
# # Zara

# %%
df_zara = pd.read_csv(os.path.join(os.getcwd(), 'data', 'Reviews_Zara.csv'))
df_zara = df_zara.replace(np.nan, '')
combined_text = ' '.join(df_zara.iloc[:, 1].astype(str))
combined_text = combined_text.lower().replace('zara', '')
combined_text = combined_text.lower().replace('app', '')

# %%
# Generate the word cloud
wordcloud = generate_wordcloud(combined_text)

# %%
get_sentiment(df_zara)

# %%
get_year_wise_reviews(df_zara)

# %% [markdown]
# # HnM

# %%
df_hnm = pd.read_csv(os.path.join(os.getcwd(), 'data', 'Reviews_HM.csv'))
combined_text = ' '.join(df_hnm.iloc[:, 2].astype(str))
combined_text = combined_text.lower().replace('H&M', '')
combined_text = combined_text.lower().replace('app', '')

# %%
# Generate the word cloud
wordcloud = generate_wordcloud(combined_text)

# %%
get_sentiment(df_hnm)

# %%
get_year_wise_reviews(df_hnm)

# %% [markdown]
# # Levis

# %%
df_levis = pd.read_csv(os.path.join(os.getcwd(), 'data', 'Reviews_Levis.csv'))
combined_text = ' '.join(df_levis.iloc[:, 2].astype(str))
combined_text = combined_text.lower().replace('levis', '')
combined_text = combined_text.lower().replace('levi', '')
combined_text = combined_text.lower().replace('app', '')

# %%
# Generate the word cloud
wordcloud = generate_wordcloud(combined_text)

# %%
get_sentiment(df_levis)

# %%
get_year_wise_reviews(df_levis)
